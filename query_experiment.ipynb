# %% [markdown]
# This notebook is dedicated to learning the query system used by GAIA.

# %%
import astropy.units as u
from astropy.coordinates.sky_coordinate import SkyCoord
from astropy.units import Quantity
from astroquery.gaia import Gaia
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %%
import numpy as np
from astroquery.simbad import Simbad

Simbad.add_votable_fields('ra(d;A;ICRS;J2017.5;2000)', 'dec(d;D;ICRS;J2017.5;2000)')
result_table = Simbad.query_object("M *", wildcard = True)
ra = result_table['RA_d_A_ICRS_J2017_5_2000']
dec = result_table['DEC_d_D_ICRS_J2017_5_2000_4']

ra = np.array([float(x) for x in ra])
dec = np.array([float(x) for x in dec])

ra = [-(360-x)*(np.pi/180) if x>180 else x*(np.pi/180) for x in ra]
dec = [x*(np.pi/180) for x in dec]

# %%
from astroquery.vizier import Vizier
import numpy as np
catalogue_list = Vizier.find_catalogs("Constellation")
Vizier.ROW_LIMIT = -1

catalog = Vizier.get_catalogs("VI/49")
ra = catalog[1]['RAJ2000']
dec = catalog[1]['DEJ2000']
ra = np.array([float(x) for x in ra])
dec = np.array([float(x) for x in dec])

ra = [-(360-x)*(np.pi/180) if x>180 else x*(np.pi/180) for x in ra]
dec = [x*(np.pi/180) for x in dec]
# Out:
# [-0.1215500000032257, -0.1391483468373031, -0.15674866589343422, -0.17434898494956538, -0.19194534210829456, -0.2095441776345613, -0.22714252446863867, -0.24473785188310881, -0.26233469773402834, -0.271131593496393, -0.2712210067139731, -0.27131336953798857, -0.2714077394906438, -0.27150460526412895, -0.2716044904572214, -0.27170734271004066, -0.2718132143824672, -0.27192257671339687, -0.27203590094172847, -0.2721527681884426, -0.27227412093133396, -0.2723994355716272, -0.272529759306873, -0.27266558082926357, -0.2728069001387969, -0.27295420592766534, -0.2731080043413517, -0.2732688015253377, -0.25554662358083247, -0.2378199426868565, -0.2200917957163086, -0.20236610966000676, -0.18463595556082016, -0.16690480662395946, -0.1491751412169622, -0.14908276093965422, -0.14899488361181695, -0.14895194851221716, -0.131243244509537, -0.11353403436137405, -0.09582684879514325, -0.08254435213539824, -0.08249541310317186, -0.08244797505410338, -0.06475476957518049, -0.0470610579507748, -0.029369842147200113, -0.01167562437731164, 0.006018366499774486, 0.02370966956981225, 0.028134201396665514, 0.028134009410447795, 0.045828174820458825, 0.06351953025037414, 0.07236775614603971, 0.07234030211690586, 0.07231386037873813, 0.08998856536758944, 0.10766559164434587, 0.1253422339486669, 0.14301578702021187, 0.1606914693934443, 0.17836655835473103, 0.19603831